# %%
import pandas as pd

# %%
cd Desktop
# Out:
# [WinError 2] The system cannot find the file specified: 'Desktop'
# C:\Users\Nishant\Desktop

# %%
from bs4 import BeautifulSoup

with open('LinkedIn.html', 'r',encoding="utf8") as f:

    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')

# %%
page = url

# %%
BeautifulSoup(page.content,'html parser')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-201de5135bbd> in <module>
# ----> 1 BeautifulSoup(page.content,'html parser')
#
# AttributeError: 'str' object has no attribute 'content'

# %%
soup
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0066)https://www.linkedin.com/mynetwork/import-contacts/saved-contacts/ --><html class="theme theme--mercado artdeco windows" lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(99+) LinkedIn</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/7438dbnn8galtczp2gk2s4bgb" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#ffffff" id="theme-color-meta-tag" name="theme-color"/>
# ...

# %%
soup.findAll(attrs = {'class' : 'contact-summary__name t-sans t-16 t-black t-bold mr1'})
# Out:
# [<span class="contact-summary__name t-sans t-16 t-black t-bold mr1">
#  <span class="visually-hidden">
#            Member’s name
#          </span>
#
#            Krishnan Iyer
#      </span>,
#  <span class="contact-summary__name t-sans t-16 t-black t-bold mr1">
#  <span class="visually-hidden">
#            Member’s name
#          </span>
#          Sajini Iyer
#      </span>,
#  <span class="contact-summary__name t-sans t-16 t-black t-bold mr1">
#  <span class="visually-hidden">
#            Member’s name
#          </span>
#
#            Elaine Ann Sumacot Gucilatar RN, CHRMP
#      </span>,
#  <span class="contact-summary__name t-sans t-16 t-black t-bold mr1">
#  <span class="visually-hidden">
#            Member’s name
#          </span>
#
#            Suresh Ramakrishnan
#      </span>,
#  <span class="contact-summary__name t-sans t-16 t-black t-bold mr1">
#  <span class="visually-hidden">
#            Member’s name
#          </span>
#          Shruti Hebbar
# ...

# %%
visually-hidden

# %%
soup.findAll(attrs = 'span',{'class' : 'visually-hidden'})
# Out:
#   File "<ipython-input-31-a87c0dde5390>", line 1
#     soup.findAll(attrs = 'span',{'class' : 'visually-hidden'})
#                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
soup.findAll('span',{'class':'visually-hidden'} )
# Out:
# [<span class="visually-hidden">
#        Status is reachable
#    </span>,
#  <span class="visually-hidden">
#            Member’s name
#          </span>,
#  <span class="visually-hidden">1st degree connection</span>,
#  <span class="visually-hidden">
#        Member’s occupation
#      </span>,
#  <span class="visually-hidden">
#        Status is offline
#        </span>,
#  <span class="visually-hidden">
#            Member’s name
#          </span>,
#  <span class="visually-hidden">
#        Status is offline
#        </span>,
#  <span class="visually-hidden">
#            Member’s name
#          </span>,
#  <span class="visually-hidden">2nd degree connection</span>,
#  <span class="visually-hidden">
#        Member’s occupation
#      </span>,
#  <span class="visually-hidden">
#        Status is offline
#        </span>,
#  <span class="visually-hidden">
#            Member’s name
#          </span>,
#  <span class="visually-hidden">2nd degree connection</span>,
# ...

# %%
data = soup.findAll('button',{'class':'abi-saved-contacts-row__description'} )

# %%
import pandas as pd

# %%
pd.options.display.max_rows
# Out:
# 9999999

# %%
f = open('Test.txt', 'w')
f.writelines(str(data,encoding='utf-8'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7ff6cab9308d> in <module>
#       1 f = open('Test.txt', 'w')
# ----> 2 f.writelines(str(data,encoding='utf-8'))
#
# TypeError: decoding to str: need a bytes-like object, ResultSet found

# %%
data.astype(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-f950f5855d34> in <module>
# ----> 1 data.astype(str)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'astype'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
with open('outfile.txt') as outfile:
   print (data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data.to_csv('lik.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-326b8a93681e> in <module>
# ----> 1 data.to_csv('lik.csv')
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'to_csv'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?
